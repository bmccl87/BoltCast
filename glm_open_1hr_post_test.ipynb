# %%
import numpy as np
import xarray as xr
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import os 
import shutil 
import glob
import numpy as np
import matplotlib.pyplot as plt
import pygrib
import pickle
import datetime
import pandas as pd
from util import boxbin 

#################################################################
# Default plotting parameters
FIGURESIZE=(10,6)
FONTSIZE=  18
plt.rcParams['figure.figsize'] = FIGURESIZE
plt.rcParams['font.size'] = FONTSIZE
plt.rcParams['xtick.labelsize'] = FONTSIZE
plt.rcParams['ytick.labelsize'] = FONTSIZE
#################################################################

# %% [markdown]
# ## Test pickle output

# %%
hr = '15'
day ='120'
yr='2019'
sat='G18'
save_dir = '/ourdisk/hpc/ai2es/bmac87/OG_datasets/GLM/'+sat+'/flashes_1hr_df/'
df = pickle.load(open(save_dir+sat+'_'+yr+'_'+day+'_'+hr+'.pkl','rb'))
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 6
#       4 sat='G18'
#       5 save_dir = '/ourdisk/hpc/ai2es/bmac87/OG_datasets/GLM/'+sat+'/flashes_1hr_df/'
# ----> 6 df = pickle.load(open(save_dir+sat+'_'+yr+'_'+day+'_'+hr+'.pkl','rb'))
#       7 df
#
# File ~/.conda/envs/pygrib/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/ourdisk/hpc/ai2es/bmac87/OG_datasets/GLM/G18/flashes_1hr_df/G18_2019_120_15.pkl'

# %%
j_days = []
for i in range(1,366):
    j_days.append(f"{i:03}")


for day in j_days:
    print(day)
    for h in ['00','01','02']:
        df_hr = pickle.load(open(save_dir+sat+'_'+yr+'_'+day+'_'+h+'.pkl','rb'))
        if h=='00':
            df_3hr = df_hr
        else:
            df_3hr = pd.concat([df_3hr,df_hr])
# Out:
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 013
# 014
# 015
# 016
# 017
# 018
# 019
# 020
# 021
# 022
# 023
# 024
# 025
# 026
# 027
# 028
# 029
# 030
# 031
# 032
# 033
# 034
# 035
# 036
# 037
# 038
# 039
# 040
# 041
# 042
# 043
# 044
# 045
# 046
# 047
# 048
# 049
# 050
# 051
# 052
# 053
# 054
# 055
# 056
# 057
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 9
#       7 print(day)
#       8 for h in ['00','01','02']:
# ----> 9     df_hr = pickle.load(open(save_dir+sat+'_'+yr+'_'+day+'_'+h+'.pkl','rb'))
#      10     if h=='09':
#      11         df_3hr = df_hr
#
# File ~/.conda/envs/pygrib/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
# ...

# %%
import xarray as xr

d_dir = '/ourdisk/hpc/ai2es/bmac87/BoltCast/GLM/G16/'
ds = xr.open_dataset(d_dir+'G16_2021_001_BC_df.nc',engine='netcdf4')
ds
# Out:
# <xarray.Dataset> Size: 276kB
# Dimensions:                           (date_time_UTC: 5113)
# Coordinates:
#   * date_time_UTC                     (date_time_UTC) datetime64[ns] 41kB 202...
# Data variables:
#     flash_lat                         (date_time_UTC) float32 20kB ...
#     flash_lon                         (date_time_UTC) float32 20kB ...
#     flash_id                          (date_time_UTC) uint16 10kB ...
#     flash_time_offset_of_first_event  (date_time_UTC) datetime64[ns] 41kB ...
#     flash_area                        (date_time_UTC) float32 20kB ...
#     flash_energy                      (date_time_UTC) float32 20kB ...
#     flash_quality_flag                (date_time_UTC) float32 20kB ...
#     minute                            (date_time_UTC) int32 20kB ...
#     hour                              (date_time_UTC) int32 20kB ...
#     day                               (date_time_UTC) int32 20kB ...
# ...
